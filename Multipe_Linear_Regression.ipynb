# %% [markdown]
# # Multiple linear regression
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Mount my Drive and use google colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# #Importing my data-set

# %%
data= pd.read_csv('/content/drive/MyDrive/Machine-Learning-NanoDegree/part(4)..Multiple Linear Regression/50_Startups.csv')
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %% [markdown]
# # Problem Discussion
# Here in this Multiple linear regression problem..
#
# I'm trying to find relation between the profit and other columns

# %% [markdown]
# # Data Preprosessing

# %%
data.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
data = pd.get_dummies(data)
data.head()
# Out:
#    R&D Spend  Administration  ...  State_Florida  State_New York
# 0  165349.20       136897.80  ...              0               1
# 1  162597.70       151377.59  ...              0               0
# 2  153441.51       101145.55  ...              1               0
# 3  144372.41       118671.85  ...              0               1
# 4  142107.34        91391.77  ...              1               0
#
# [5 rows x 7 columns]

# %%
x=data.drop(['Profit', 'State_New York'], axis=1)
y=data['Profit']

# %%
# split data to Train set and Test set
from sklearn.model_selection import train_test_split
x_train , x_test ,y_train , y_test = train_test_split(x,y,test_size=0.2 ,random_state=0)

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# # Model Accuracy

# %%
y_pred=regressor.predict(x_test)
y_pred_train=regressor.predict(x_train)
